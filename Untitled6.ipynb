# %% [markdown]
# <a href="https://colab.research.google.com/github/oceanensley14/HANGMAN-GAME/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
  word = random.choice(["school", "taste", "practical", "density", "lonely", "wife", "graduate", "coin", "insert", "legislation"])
  alpha = "abcdefghijklmnopqrstuvwxyz"
  turns = 6
  guessmade = ''

  while len(word) > 0:
    main = ""
    missed = 0

    for letter in word:
      if letter in guessmade:
        main = main + letter
      else:
        main = main + "_" + " "
    if main == word:
      print(main)
      print("You Win!")
      break

    print("Guess the word: " , main)
    guess = input()
    if guess in alpha:
      guessmade = guessmade + guess
    else:
      print("Enter a valid character")
      guess = input()

    if guess not in word:
      turns = turns - 1
      if turns == 5:
        print("5 turns left")
        print("------------")
        print("      ]     ")
        print("      O     ")
      if turns == 4:
        print("4 turns left")
        print("------------")
        print("      ]     ")
        print("      O     ")
        print("      |     ")
      if turns == 3:
        print("3 turns left")
        print("------------")
        print("      ]     ")
        print("      O     ")
        print("      |\    ")
      if turns == 2:
        print("2 turns left")
        print("------------")
        print("      ]     ")
        print("      O     ")
        print("     /|\    ")
      if turns == 1:
        print("1 turns left")
        print("------------")
        print("      ]     ")
        print("      O     ")
        print("     /|\    ")
        print("       \     ")
      if turns == 0:
        print("Dead...")
        print("------------")
        print("      ]     ")
        print("      O     ")
        print("     /|\    ")
        print("     / \    ")
        print("-GAME  OVER-")
        break

name = input("What's your name?")
print("Welcome", name, "to HANGMAN!!!")
print("Try to attempt the word in 6 attempts")
hangman()
print()
# Out:
# What's your name?Ocean
# Welcome Ocean to HANGMAN!!!
# Try to attempt the word in 6 attempts
# Guess the word:  _ _ _ _ _ _ _ _ _ _ _
# g
# Guess the word:  _ _ g_ _ _ _ _ _ _ _
# y
# 5 turns left
# ------------
#       ]
#       O
# Guess the word:  _ _ g_ _ _ _ _ _ _ _
# e
# Guess the word:  _ eg_ _ _ _ _ _ _ _
# j
# 4 turns left
# ------------
#       ]
#       O
#       |
# Guess the word:  _ eg_ _ _ _ _ _ _ _
# k
# 3 turns left
# ------------
#       ]
#       O
#       |\
# Guess the word:  _ eg_ _ _ _ _ _ _ _
# z
# 2 turns left
# ------------
#       ]
#       O
#      /|\
# Guess the word:  _ eg_ _ _ _ _ _ _ _
# x
# 1 turns left
# ------------
#       ]
#       O
#      /|\
#        \
# Guess the word:  _ eg_ _ _ _ _ _ _ _
# c
# Dead...
# ------------
#       ]
#       O
#      /|\
#      / \
# -GAME  OVER-
