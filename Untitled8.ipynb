# %% [markdown]
# <a href="https://colab.research.google.com/github/oceanensley14/HANGMAN-GAME/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string
from words import words
from IPython.display import clear_output

name = input("What is your name? ")
print("Well", name, ", WELCOME TO HANGMAN")
length = input("How long should the word be? ")
print("Try to guess the word as best as possible")
print()

def get_valid_word(words):
  word = random.choice([word for word in words if len(word) == int(length)])
  while '-' in word or ' ' in word:
    word = random.choice(words)
  return word.upper()

def hangman():
    word = get_valid_word(words)
    word_letters = set(word)
    alphabet = set(string.ascii_uppercase)
    used_letters = set()

    lives = 7

    while len(word_letters) > 0 and lives > 0:
        print('You have', lives, 'lives left and you have used these letters: ', ' '.join(used_letters))
        word_list = [letter if letter in used_letters else '-' for letter in word]
        print('Current word: ', ' '.join(word_list))
        clear_output

        user_letter = input('Guess a letter: ').upper()
        if user_letter in alphabet - used_letters:
            used_letters.add(user_letter)
            if user_letter in word_letters:
                word_letters.remove(user_letter)
                print('')
            else:
                lives = lives - 1
                print('\nYour letter,', user_letter, 'is not in the word.')
                if lives == 6:
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("              |            ")
                  print("              |            ")
                  print("              |            ")
                  print("______________+____________")
                if lives == 5:
                  clear_output
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("      👕      |            ")
                  print("              |            ")
                  print("              |            ")
                  print("______________+____________")
                if lives == 4:
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("     /👕      |            ")
                  print("              |            ")
                  print("              |            ")
                  print("______________+____________")
                if lives == 3:
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("     /👕\     |            ")
                  print("              |            ")
                  print("              |            ")
                  print("______________+____________")
                if lives == 2:
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("     /👕\     |            ")
                  print("      👖      |            ")
                  print("              |            ")
                  print("______________+____________")
                if lives == 1:
                  print("       /``````|            ")
                  print("      😵      |            ")
                  print("     /👕\     |            ")
                  print("      👖      |            ")
                  print("       👞     |            ")
                  print("______________+____________")
        elif user_letter in used_letters:
            print('\nYou have already used that letter. Guess another letter.')
        else:
            print('\nThat is not a valid letter.')
    if lives == 0:
        print("Better luck next time", name,". The word was", word)
        print("       /``````|            ")
        print("      😵      |            ")
        print("     /👕\     |            ")
        print("      👖      |            ")
        print("     👞👞     |            ")
        print("______________+____________")
    else:
        print("Well done", name,"! You guessed the word", word, '!!')

if __name__ == '__main__':
    hangman()
# Out:
# What is your name? Daniel
# Well Daniel , WELCOME TO HANGMAN
# How long should the word be? 4
# Try to guess the word as best as possible
#
# You have 7 lives left and you have used these letters:
# Current word:  - - - -
# Guess a letter: l
#
# You have 7 lives left and you have used these letters:  L
# Current word:  - - L L
# Guess a letter: c
#
# Your letter, C is not in the word.
#        /``````|
#       😵      |
#               |
#               |
#               |
# ______________+____________
# You have 6 lives left and you have used these letters:  C L
# Current word:  - - L L
# Guess a letter: r
#
# Your letter, R is not in the word.
#        /``````|
#       😵      |
#       👕      |
#               |
#               |
# ______________+____________
# You have 5 lives left and you have used these letters:  C L R
# Current word:  - - L L
# Guess a letter: s
#
# Your letter, S is not in the word.
#        /``````|
#       😵      |
#      /👕      |
#               |
# ...
